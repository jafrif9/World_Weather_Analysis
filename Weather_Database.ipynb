# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_describe = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | port lincoln
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | rondonopolis
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | winthrop
# Processing Record 11 of Set 1 | port hardy
# Processing Record 12 of Set 1 | vestmannaeyjar
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | geraldton
# Processing Record 15 of Set 1 | atar
# Processing Record 16 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | yuyao
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | guymon
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | wamba
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | muros
# Processing Record 26 of Set 1 | salalah
# Processing Record 27 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 1 | rocha
# Processing Record 29 of Set 1 | faanui
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | nome
# Processing Record 32 of Set 1 | baruun-urt
# Processing Record 33 of Set 1 | moose factory
# Processing Record 34 of Set 1 | vila franca do campo
# Processing Record 35 of Set 1 | wewak
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | sarakhs
# Processing Record 39 of Set 1 | nyandoma
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | aykhal
# Processing Record 43 of Set 1 | hambantota
# Processing Record 44 of Set 1 | ilulissat
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | sobolevo
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | deh rawud
# City not found. Skipping...
# Processing Record 50 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | bud
# Processing Record 4 of Set 2 | nautla
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | la ronge
# Processing Record 7 of Set 2 | ornes
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | coquimbo
# Processing Record 12 of Set 2 | gillette
# Processing Record 13 of Set 2 | sao joao da barra
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | knysna
# Processing Record 16 of Set 2 | husavik
# Processing Record 17 of Set 2 | dmitrovsk-orlovskiy
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | mizdah
# Processing Record 21 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 2 | hashtrud
# Processing Record 23 of Set 2 | jingcheng
# Processing Record 24 of Set 2 | sao filipe
# Processing Record 25 of Set 2 | uk
# City not found. Skipping...
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | turukhansk
# Processing Record 28 of Set 2 | homer
# Processing Record 29 of Set 2 | teya
# Processing Record 30 of Set 2 | komsomolskiy
# Processing Record 31 of Set 2 | waipawa
# Processing Record 32 of Set 2 | ishigaki
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | gonaives
# Processing Record 35 of Set 2 | vicar
# Processing Record 36 of Set 2 | jalu
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | boguchany
# Processing Record 40 of Set 2 | nemuro
# Processing Record 41 of Set 2 | grenfell
# Processing Record 42 of Set 2 | shimizu
# Processing Record 43 of Set 2 | buraydah
# Processing Record 44 of Set 2 | aklavik
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | kannangad
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | mitu
# Processing Record 50 of Set 2 | dukat
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | panzhihua
# Processing Record 3 of Set 3 | kapaa
# Processing Record 4 of Set 3 | laguna
# Processing Record 5 of Set 3 | havelock
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | mataura
# Processing Record 8 of Set 3 | biak
# Processing Record 9 of Set 3 | pariquera-acu
# City not found. Skipping...
# Processing Record 10 of Set 3 | oakley
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | porto belo
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | peterhead
# Processing Record 15 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 3 | moerai
# Processing Record 17 of Set 3 | sur
# Processing Record 18 of Set 3 | muisne
# Processing Record 19 of Set 3 | bonthe
# Processing Record 20 of Set 3 | grindavik
# Processing Record 21 of Set 3 | kodinsk
# Processing Record 22 of Set 3 | lagoa
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 3 | kavaratti
# Processing Record 25 of Set 3 | vanavara
# Processing Record 26 of Set 3 | inirida
# Processing Record 27 of Set 3 | virginia beach
# Processing Record 28 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 3 | vrangel
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | college
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | vinh
# Processing Record 36 of Set 3 | doha
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | sturgeon bay
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | urzhum
# Processing Record 41 of Set 3 | nhulunbuy
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | bairiki
# Processing Record 45 of Set 3 | strezhevoy
# Processing Record 46 of Set 3 | aksarka
# Processing Record 47 of Set 3 | belaya gora
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | whitehorse
# Processing Record 50 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | severnyy-kospashskiy
# Processing Record 4 of Set 4 | gat
# Processing Record 5 of Set 4 | ambilobe
# Processing Record 6 of Set 4 | montes altos
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | mareeba
# Processing Record 9 of Set 4 | maniitsoq
# Processing Record 10 of Set 4 | rio rancho
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | san policarpo
# Processing Record 13 of Set 4 | coro
# Processing Record 14 of Set 4 | ozatlan
# Processing Record 15 of Set 4 | matamoros
# Processing Record 16 of Set 4 | blackwater
# Processing Record 17 of Set 4 | saint-augustin
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | fuling
# Processing Record 20 of Set 4 | caconda
# Processing Record 21 of Set 4 | zhireken
# Processing Record 22 of Set 4 | bubaque
# Processing Record 23 of Set 4 | columbus
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 4 | maswa
# Processing Record 26 of Set 4 | butaritari
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | constitucion
# Processing Record 29 of Set 4 | zhigansk
# Processing Record 30 of Set 4 | barrow
# Processing Record 31 of Set 4 | copala
# Processing Record 32 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | tongliao
# Processing Record 35 of Set 4 | vardo
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | marawi
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | pacifica
# Processing Record 44 of Set 4 | umm lajj
# Processing Record 45 of Set 4 | mangrol
# Processing Record 46 of Set 4 | labuhan
# Processing Record 47 of Set 4 | shingu
# Processing Record 48 of Set 4 | nong chik
# Processing Record 49 of Set 4 | tuatapere
# Processing Record 50 of Set 4 | bekhtery
# Processing Record 1 of Set 5 | talnakh
# Processing Record 2 of Set 5 | comodoro rivadavia
# Processing Record 3 of Set 5 | puerto el triunfo
# Processing Record 4 of Set 5 | mubi
# Processing Record 5 of Set 5 | cairns
# Processing Record 6 of Set 5 | tazovskiy
# Processing Record 7 of Set 5 | nago
# Processing Record 8 of Set 5 | pochutla
# Processing Record 9 of Set 5 | marang
# Processing Record 10 of Set 5 | kununurra
# Processing Record 11 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | asau
# Processing Record 14 of Set 5 | lebu
# Processing Record 15 of Set 5 | padang
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | yulara
# Processing Record 18 of Set 5 | severo-kurilsk
# Processing Record 19 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | don sak
# Processing Record 22 of Set 5 | harper
# Processing Record 23 of Set 5 | bojonegoro
# Processing Record 24 of Set 5 | kathmandu
# Processing Record 25 of Set 5 | los llanos de aridane
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | hobyo
# Processing Record 28 of Set 5 | tautira
# Processing Record 29 of Set 5 | cherskiy
# Processing Record 30 of Set 5 | punto fijo
# Processing Record 31 of Set 5 | lensk
# Processing Record 32 of Set 5 | roma
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | tarata
# Processing Record 35 of Set 5 | pec
# Processing Record 36 of Set 5 | hirara
# Processing Record 37 of Set 5 | yuanping
# Processing Record 38 of Set 5 | sergeyevka
# Processing Record 39 of Set 5 | fortuna
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | grandview
# Processing Record 42 of Set 5 | hovd
# Processing Record 43 of Set 5 | chimbote
# Processing Record 44 of Set 5 | leh
# Processing Record 45 of Set 5 | denau
# City not found. Skipping...
# Processing Record 46 of Set 5 | margate
# Processing Record 47 of Set 5 | victoria
# Processing Record 48 of Set 5 | skelleftea
# Processing Record 49 of Set 5 | narragansett
# Processing Record 50 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | meulaboh
# Processing Record 4 of Set 6 | nelson bay
# Processing Record 5 of Set 6 | puerto madryn
# Processing Record 6 of Set 6 | ola
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | hervey bay
# Processing Record 9 of Set 6 | gold coast
# Processing Record 10 of Set 6 | praia
# Processing Record 11 of Set 6 | zeya
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 14 of Set 6 | lardos
# Processing Record 15 of Set 6 | sabang
# Processing Record 16 of Set 6 | panama city
# Processing Record 17 of Set 6 | donji komren
# City not found. Skipping...
# Processing Record 18 of Set 6 | ulaangom
# Processing Record 19 of Set 6 | joshimath
# Processing Record 20 of Set 6 | thompson
# Processing Record 21 of Set 6 | yining
# Processing Record 22 of Set 6 | roald
# Processing Record 23 of Set 6 | pevek
# Processing Record 24 of Set 6 | larsnes
# Processing Record 25 of Set 6 | anderson
# Processing Record 26 of Set 6 | northam
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | dera bugti
# Processing Record 29 of Set 6 | cartagena del chaira
# Processing Record 30 of Set 6 | namibe
# Processing Record 31 of Set 6 | westport
# Processing Record 32 of Set 6 | manokwari
# Processing Record 33 of Set 6 | hay river
# Processing Record 34 of Set 6 | narsaq
# Processing Record 35 of Set 6 | nara
# Processing Record 36 of Set 6 | pacific grove
# Processing Record 37 of Set 6 | urucara
# Processing Record 38 of Set 6 | waitati
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 6 | berlevag
# Processing Record 41 of Set 6 | huoqiu
# Processing Record 42 of Set 6 | sioux lookout
# Processing Record 43 of Set 6 | lotung
# City not found. Skipping...
# Processing Record 44 of Set 6 | veraval
# Processing Record 45 of Set 6 | ippy
# Processing Record 46 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 6 | kukmor
# Processing Record 48 of Set 6 | wilmington
# Processing Record 49 of Set 6 | baykit
# Processing Record 50 of Set 6 | samarai
# Processing Record 1 of Set 7 | kiruna
# Processing Record 2 of Set 7 | honiara
# Processing Record 3 of Set 7 | pueblo nuevo
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | kondoa
# Processing Record 6 of Set 7 | bowmore
# Processing Record 7 of Set 7 | huarmey
# Processing Record 8 of Set 7 | baherden
# Processing Record 9 of Set 7 | nampula
# Processing Record 10 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 7 | pingliang
# Processing Record 12 of Set 7 | nyurba
# Processing Record 13 of Set 7 | buchanan
# Processing Record 14 of Set 7 | sechura
# Processing Record 15 of Set 7 | longyearbyen
# Processing Record 16 of Set 7 | mikhaylovskoye
# Processing Record 17 of Set 7 | camacari
# Processing Record 18 of Set 7 | portland
# Processing Record 19 of Set 7 | harbour breton
# Processing Record 20 of Set 7 | te anau
# Processing Record 21 of Set 7 | khani
# Processing Record 22 of Set 7 | itaituba
# Processing Record 23 of Set 7 | pedra branca
# Processing Record 24 of Set 7 | olavarria
# Processing Record 25 of Set 7 | purpe
# Processing Record 26 of Set 7 | port said
# Processing Record 27 of Set 7 | trincomalee
# Processing Record 28 of Set 7 | nioro
# Processing Record 29 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 7 | trairi
# Processing Record 31 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 32 of Set 7 | mayumba
# Processing Record 33 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 7 | pathein
# Processing Record 35 of Set 7 | havoysund
# Processing Record 36 of Set 7 | cornelio procopio
# Processing Record 37 of Set 7 | port macquarie
# Processing Record 38 of Set 7 | zapolyarnyy
# Processing Record 39 of Set 7 | bloemfontein
# Processing Record 40 of Set 7 | aloleng
# Processing Record 41 of Set 7 | suntar
# Processing Record 42 of Set 7 | kattivakkam
# Processing Record 43 of Set 7 | aswan
# Processing Record 44 of Set 7 | okha
# Processing Record 45 of Set 7 | poum
# Processing Record 46 of Set 7 | kalevala
# Processing Record 47 of Set 7 | hofn
# Processing Record 48 of Set 7 | kawalu
# Processing Record 49 of Set 7 | wattegama
# Processing Record 50 of Set 7 | killorglin
# Processing Record 1 of Set 8 | masuguru
# Processing Record 2 of Set 8 | kieta
# Processing Record 3 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 8 | swift current
# Processing Record 5 of Set 8 | benguela
# Processing Record 6 of Set 8 | batsfjord
# Processing Record 7 of Set 8 | aripuana
# Processing Record 8 of Set 8 | gubkinskiy
# Processing Record 9 of Set 8 | tocopilla
# Processing Record 10 of Set 8 | nanortalik
# Processing Record 11 of Set 8 | burns lake
# Processing Record 12 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 8 | saldanha
# Processing Record 14 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 8 | naze
# Processing Record 16 of Set 8 | taoudenni
# Processing Record 17 of Set 8 | gazojak
# Processing Record 18 of Set 8 | iganga
# Processing Record 19 of Set 8 | dasoguz
# Processing Record 20 of Set 8 | nowogard
# Processing Record 21 of Set 8 | vanderhoof
# Processing Record 22 of Set 8 | farah
# Processing Record 23 of Set 8 | kudahuvadhoo
# Processing Record 24 of Set 8 | cockburn town
# Processing Record 25 of Set 8 | vila
# Processing Record 26 of Set 8 | ahipara
# Processing Record 27 of Set 8 | kosh-agach
# Processing Record 28 of Set 8 | balkhash
# Processing Record 29 of Set 8 | tomatlan
# Processing Record 30 of Set 8 | salinopolis
# Processing Record 31 of Set 8 | praia da vitoria
# Processing Record 32 of Set 8 | provideniya
# Processing Record 33 of Set 8 | grand gaube
# Processing Record 34 of Set 8 | surt
# Processing Record 35 of Set 8 | kijang
# Processing Record 36 of Set 8 | ulagan
# Processing Record 37 of Set 8 | rutana
# Processing Record 38 of Set 8 | san rafael
# Processing Record 39 of Set 8 | sombrio
# Processing Record 40 of Set 8 | shache
# Processing Record 41 of Set 8 | imperia
# Processing Record 42 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 43 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 8 | ixtapa
# Processing Record 45 of Set 8 | tilichiki
# Processing Record 46 of Set 8 | effium
# Processing Record 47 of Set 8 | chokurdakh
# Processing Record 48 of Set 8 | ostroleka
# Processing Record 49 of Set 8 | camacha
# Processing Record 50 of Set 8 | riyadh
# Processing Record 1 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 9 | ferzikovo
# Processing Record 3 of Set 9 | kuryk
# Processing Record 4 of Set 9 | mogadishu
# Processing Record 5 of Set 9 | sinnamary
# Processing Record 6 of Set 9 | san cristobal
# Processing Record 7 of Set 9 | bilma
# Processing Record 8 of Set 9 | luau
# Processing Record 9 of Set 9 | vung tau
# Processing Record 10 of Set 9 | mackenzie
# Processing Record 11 of Set 9 | chilliwack
# Processing Record 12 of Set 9 | mirpur mathelo
# Processing Record 13 of Set 9 | hami
# Processing Record 14 of Set 9 | airai
# Processing Record 15 of Set 9 | carutapera
# Processing Record 16 of Set 9 | saint-pierre
# Processing Record 17 of Set 9 | brandon
# Processing Record 18 of Set 9 | sheridan
# Processing Record 19 of Set 9 | luanda
# Processing Record 20 of Set 9 | san quintin
# Processing Record 21 of Set 9 | esperance
# Processing Record 22 of Set 9 | sabha
# Processing Record 23 of Set 9 | cedar city
# Processing Record 24 of Set 9 | fairbanks
# Processing Record 25 of Set 9 | carnarvon
# Processing Record 26 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 9 | berbera
# Processing Record 28 of Set 9 | victor harbor
# Processing Record 29 of Set 9 | rawson
# Processing Record 30 of Set 9 | duldurga
# Processing Record 31 of Set 9 | gamba
# Processing Record 32 of Set 9 | quatre cocos
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 9 | koumac
# Processing Record 36 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 9 | malindi
# Processing Record 38 of Set 9 | savonlinna
# Processing Record 39 of Set 9 | haimen
# Processing Record 40 of Set 9 | high prairie
# Processing Record 41 of Set 9 | kailua
# Processing Record 42 of Set 9 | blagoyevo
# Processing Record 43 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 44 of Set 9 | swellendam
# Processing Record 45 of Set 9 | akyab
# Processing Record 46 of Set 9 | sistranda
# Processing Record 47 of Set 9 | souillac
# Processing Record 48 of Set 9 | marienburg
# Processing Record 49 of Set 9 | gazanjyk
# Processing Record 50 of Set 9 | bathsheba
# Processing Record 1 of Set 10 | alto paraguai
# Processing Record 2 of Set 10 | fully
# Processing Record 3 of Set 10 | saint george
# Processing Record 4 of Set 10 | suez
# Processing Record 5 of Set 10 | peniche
# Processing Record 6 of Set 10 | nouakchott
# Processing Record 7 of Set 10 | maceio
# Processing Record 8 of Set 10 | presidencia roque saenz pena
# Processing Record 9 of Set 10 | ginda
# Processing Record 10 of Set 10 | key largo
# Processing Record 11 of Set 10 | kavieng
# Processing Record 12 of Set 10 | burnie
# Processing Record 13 of Set 10 | vostok
# Processing Record 14 of Set 10 | omboue
# Processing Record 15 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 10 | duz
# City not found. Skipping...
# Processing Record 17 of Set 10 | dunedin
# Processing Record 18 of Set 10 | okhotsk
# Processing Record 19 of Set 10 | avarua
# Processing Record 20 of Set 10 | kropotkin
# Processing Record 21 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 22 of Set 10 | minab
# Processing Record 23 of Set 10 | isangel
# Processing Record 24 of Set 10 | shahrud
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 27 of Set 10 | burriana
# Processing Record 28 of Set 10 | ust-kulom
# Processing Record 29 of Set 10 | pandan
# Processing Record 30 of Set 10 | anzio
# Processing Record 31 of Set 10 | ajdabiya
# Processing Record 32 of Set 10 | el mante
# Processing Record 33 of Set 10 | mehamn
# Processing Record 34 of Set 10 | menongue
# Processing Record 35 of Set 10 | kiama
# Processing Record 36 of Set 10 | sorland
# Processing Record 37 of Set 10 | snasa
# Processing Record 38 of Set 10 | san luis
# Processing Record 39 of Set 10 | preobrazheniye
# Processing Record 40 of Set 10 | port-gentil
# Processing Record 41 of Set 10 | preeceville
# Processing Record 42 of Set 10 | marquette
# Processing Record 43 of Set 10 | lavrentiya
# Processing Record 44 of Set 10 | darhan
# Processing Record 45 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 10 | kitaibaraki
# Processing Record 47 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 48 of Set 10 | capela do alto
# Processing Record 49 of Set 10 | zihuatanejo
# Processing Record 50 of Set 10 | puerto escondido
# Processing Record 1 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 2 of Set 11 | nishihara
# Processing Record 3 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 11 | murray bridge
# Processing Record 5 of Set 11 | pedernales
# Processing Record 6 of Set 11 | rodrigues alves
# Processing Record 7 of Set 11 | talcahuano
# Processing Record 8 of Set 11 | rudnogorsk
# Processing Record 9 of Set 11 | gorele
# Processing Record 10 of Set 11 | nanakuli
# Processing Record 11 of Set 11 | balaipungut
# Processing Record 12 of Set 11 | makubetsu
# Processing Record 13 of Set 11 | willowmore
# Processing Record 14 of Set 11 | mochalishche
# Processing Record 15 of Set 11 | sigayevo
# Processing Record 16 of Set 11 | ponta delgada
# Processing Record 17 of Set 11 | eydhafushi
# Processing Record 18 of Set 11 | araxa
# Processing Record 19 of Set 11 | tessalit
# Processing Record 20 of Set 11 | guerrero negro
# Processing Record 21 of Set 11 | fonte boa
# Processing Record 22 of Set 11 | buin
# Processing Record 23 of Set 11 | kantang
# Processing Record 24 of Set 11 | coos bay
# Processing Record 25 of Set 11 | belmonte
# Processing Record 26 of Set 11 | yashan
# Processing Record 27 of Set 11 | kharian
# Processing Record 28 of Set 11 | tobermory
# Processing Record 29 of Set 11 | oranjemund
# Processing Record 30 of Set 11 | omsukchan
# Processing Record 31 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 32 of Set 11 | katherine
# Processing Record 33 of Set 11 | cuenca
# Processing Record 34 of Set 11 | cuajinicuilapa
# Processing Record 35 of Set 11 | kon tum
# Processing Record 36 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 37 of Set 11 | guaiba
# Processing Record 38 of Set 11 | evinayong
# Processing Record 39 of Set 11 | oussouye
# Processing Record 40 of Set 11 | tateyama
# Processing Record 41 of Set 11 | guipavas
# Processing Record 42 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 11 | rio claro
# Processing Record 44 of Set 11 | el alto
# Processing Record 45 of Set 11 | makakilo city
# Processing Record 46 of Set 11 | dong hoi
# Processing Record 47 of Set 11 | noumea
# Processing Record 48 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 49 of Set 11 | namatanai
# Processing Record 50 of Set 11 | dom pedrito
# Processing Record 1 of Set 12 | acarau
# Processing Record 2 of Set 12 | alyangula
# Processing Record 3 of Set 12 | iqaluit
# Processing Record 4 of Set 12 | port antonio
# Processing Record 5 of Set 12 | taywarah
# Processing Record 6 of Set 12 | kontagora
# Processing Record 7 of Set 12 | saryg-sep
# Processing Record 8 of Set 12 | bundaberg
# Processing Record 9 of Set 12 | baza
# Processing Record 10 of Set 12 | presque isle
# Processing Record 11 of Set 12 | tukrah
# Processing Record 12 of Set 12 | chardara
# Processing Record 13 of Set 12 | manavalakurichi
# Processing Record 14 of Set 12 | shimoda
# Processing Record 15 of Set 12 | acapulco
# Processing Record 16 of Set 12 | buala
# Processing Record 17 of Set 12 | shwebo
# Processing Record 18 of Set 12 | kayerkan
# Processing Record 19 of Set 12 | rio grande
# Processing Record 20 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 12 | yumen
# Processing Record 22 of Set 12 | ocampo
# Processing Record 23 of Set 12 | imbituba
# Processing Record 24 of Set 12 | camacupa
# Processing Record 25 of Set 12 | butembo
# Processing Record 26 of Set 12 | tonj
# Processing Record 27 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 12 | novoagansk
# Processing Record 29 of Set 12 | waiuku
# Processing Record 30 of Set 12 | lekoni
# Processing Record 31 of Set 12 | pangody
# Processing Record 32 of Set 12 | senneterre
# Processing Record 33 of Set 12 | voi
# Processing Record 34 of Set 12 | gwadar
# Processing Record 35 of Set 12 | yuganets
# Processing Record 36 of Set 12 | bambanglipuro
# Processing Record 37 of Set 12 | cururupu
# Processing Record 38 of Set 12 | tiarei
# Processing Record 39 of Set 12 | dakar
# Processing Record 40 of Set 12 | keflavik
# Processing Record 41 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 12 | kazachinskoye
# Processing Record 43 of Set 12 | caravelas
# Processing Record 44 of Set 12 | bima
# Processing Record 45 of Set 12 | catabola
# Processing Record 46 of Set 12 | cassia
# Processing Record 47 of Set 12 | ravar
# Processing Record 48 of Set 12 | mayo
# Processing Record 49 of Set 12 | mukhen
# Processing Record 50 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 13 | yar-sale
# Processing Record 2 of Set 13 | coruripe
# Processing Record 3 of Set 13 | banyo
# Processing Record 4 of Set 13 | elko
# Processing Record 5 of Set 13 | avera
# Processing Record 6 of Set 13 | dubbo
# Processing Record 7 of Set 13 | mezhova
# Processing Record 8 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 10 of Set 13 | chabahar
# Processing Record 11 of Set 13 | pavlovo
# Processing Record 12 of Set 13 | parauna
# Processing Record 13 of Set 13 | bogorodskoye
# Processing Record 14 of Set 13 | beitbridge
# Processing Record 15 of Set 13 | guane
# Processing Record 16 of Set 13 | alizai
# Processing Record 17 of Set 13 | healesville
# Processing Record 18 of Set 13 | golden
# Processing Record 19 of Set 13 | general roca
# Processing Record 20 of Set 13 | winneba
# Processing Record 21 of Set 13 | denison
# Processing Record 22 of Set 13 | mondeville
# Processing Record 23 of Set 13 | daru
# Processing Record 24 of Set 13 | wabana
# Processing Record 25 of Set 13 | la macarena
# Processing Record 26 of Set 13 | tsuruoka
# Processing Record 27 of Set 13 | tsurugi
# Processing Record 28 of Set 13 | bowen
# Processing Record 29 of Set 13 | vorontsovka
# Processing Record 30 of Set 13 | garwolin
# Processing Record 31 of Set 13 | tenosique
# Processing Record 32 of Set 13 | moussoro
# Processing Record 33 of Set 13 | malakal
# Processing Record 34 of Set 13 | kungurtug
# Processing Record 35 of Set 13 | olinala
# Processing Record 36 of Set 13 | zhanaozen
# Processing Record 37 of Set 13 | skibbereen
# Processing Record 38 of Set 13 | lakes entrance
# Processing Record 39 of Set 13 | prado
# Processing Record 40 of Set 13 | alice
# Processing Record 41 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 13 | dunda
# Processing Record 43 of Set 13 | kahului
# Processing Record 44 of Set 13 | inverness
# Processing Record 45 of Set 13 | iquitos
# Processing Record 46 of Set 13 | ingham
# Processing Record 47 of Set 13 | xianyang
# Processing Record 48 of Set 13 | merrill
# Processing Record 49 of Set 13 | bloomfield
# Processing Record 50 of Set 13 | villacarrillo
# Processing Record 1 of Set 14 | siocon
# Processing Record 2 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 14 | ilheus
# Processing Record 4 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 14 | rapid valley
# Processing Record 6 of Set 14 | banda aceh
# Processing Record 7 of Set 14 | bourail
# Processing Record 8 of Set 14 | abu samrah
# Processing Record 9 of Set 14 | pouembout
# Processing Record 10 of Set 14 | carauari
# Processing Record 11 of Set 14 | dashitou
# Processing Record 12 of Set 14 | mount pleasant
# Processing Record 13 of Set 14 | kitimat
# Processing Record 14 of Set 14 | teodoro sampaio
# Processing Record 15 of Set 14 | eureka
# Processing Record 16 of Set 14 | orlik
# Processing Record 17 of Set 14 | marshall
# Processing Record 18 of Set 14 | kalmunai
# Processing Record 19 of Set 14 | igrim
# Processing Record 20 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 14 | alice springs
# Processing Record 22 of Set 14 | dinghai
# Processing Record 23 of Set 14 | banning
# Processing Record 24 of Set 14 | turan
# Processing Record 25 of Set 14 | plettenberg bay
# Processing Record 26 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 14 | santa isabel do rio negro
# Processing Record 28 of Set 14 | chokwe
# Processing Record 29 of Set 14 | kourou
# Processing Record 30 of Set 14 | brae
# Processing Record 31 of Set 14 | havre
# Processing Record 32 of Set 14 | mount gambier
# Processing Record 33 of Set 14 | sola
# Processing Record 34 of Set 14 | bushenyi
# Processing Record 35 of Set 14 | tura
# Processing Record 36 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 37 of Set 14 | alakurtti
# Processing Record 38 of Set 14 | nabire
# Processing Record 39 of Set 14 | zaysan
# Processing Record 40 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 14 | astara
# Processing Record 42 of Set 14 | batagay-alyta
# Processing Record 43 of Set 14 | antalaha
# Processing Record 44 of Set 14 | manubah
# City not found. Skipping...
# Processing Record 45 of Set 14 | west odessa
# Processing Record 46 of Set 14 | kamaishi
# Processing Record 47 of Set 14 | goderich
# Processing Record 48 of Set 14 | saint-felicien
# Processing Record 49 of Set 14 | kamenka
# Processing Record 50 of Set 14 | cua
# Processing Record 1 of Set 15 | beringovskiy
# Processing Record 2 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 15 | tabou
# Processing Record 4 of Set 15 | chicama
# Processing Record 5 of Set 15 | ust-omchug
# Processing Record 6 of Set 15 | erzin
# Processing Record 7 of Set 15 | gualeguay
# Processing Record 8 of Set 15 | weymouth
# Processing Record 9 of Set 15 | rajula
# Processing Record 10 of Set 15 | walvis bay
# Processing Record 11 of Set 15 | tongren
# Processing Record 12 of Set 15 | codrington
# Processing Record 13 of Set 15 | onokhoy
# Processing Record 14 of Set 15 | khandyga
# Processing Record 15 of Set 15 | stornoway
# Processing Record 16 of Set 15 | jhalida
# Processing Record 17 of Set 15 | itarema
# Processing Record 18 of Set 15 | kloulklubed
# Processing Record 19 of Set 15 | iraray
# Processing Record 20 of Set 15 | lorengau
# Processing Record 21 of Set 15 | mlonggo
# Processing Record 22 of Set 15 | pauini
# Processing Record 23 of Set 15 | nagato
# Processing Record 24 of Set 15 | canutama
# Processing Record 25 of Set 15 | visby
# Processing Record 26 of Set 15 | ust-tsilma
# Processing Record 27 of Set 15 | lasa
# Processing Record 28 of Set 15 | chapais
# Processing Record 29 of Set 15 | ormara
# Processing Record 30 of Set 15 | puerto carreno
# Processing Record 31 of Set 15 | gabaldon
# Processing Record 32 of Set 15 | north bend
# Processing Record 33 of Set 15 | terre haute
# Processing Record 34 of Set 15 | manta
# Processing Record 35 of Set 15 | chumikan
# Processing Record 36 of Set 15 | karlstad
# Processing Record 37 of Set 15 | ayna
# Processing Record 38 of Set 15 | sterlibashevo
# Processing Record 39 of Set 15 | skaelskor
# Processing Record 40 of Set 15 | henties bay
# Processing Record 41 of Set 15 | zarand
# Processing Record 42 of Set 15 | lubao
# Processing Record 43 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 15 | hemnesberget
# Processing Record 45 of Set 15 | sambava
# Processing Record 46 of Set 15 | atambua
# Processing Record 47 of Set 15 | trapani
# Processing Record 48 of Set 15 | kirksville
# Processing Record 49 of Set 15 | safford
# Processing Record 50 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 16 | ryotsu
# Processing Record 2 of Set 16 | bandarbeyla
# Processing Record 3 of Set 16 | mariinskiy posad
# Processing Record 4 of Set 16 | sakakah
# Processing Record 5 of Set 16 | meybod
# Processing Record 6 of Set 16 | cabrera
# Processing Record 7 of Set 16 | sovetskiy
# Processing Record 8 of Set 16 | prince rupert
# Processing Record 9 of Set 16 | shu
# Processing Record 10 of Set 16 | ketchikan
# Processing Record 11 of Set 16 | finsterwalde
# Processing Record 12 of Set 16 | warner robins
# Processing Record 13 of Set 16 | almeirim
# Processing Record 14 of Set 16 | karaton
# Processing Record 15 of Set 16 | kristiansund
# Processing Record 16 of Set 16 | honningsvag
# Processing Record 17 of Set 16 | xining
# Processing Record 18 of Set 16 | tuntum
# Processing Record 19 of Set 16 | jonesboro
# Processing Record 20 of Set 16 | vysokopillya
# Processing Record 21 of Set 16 | saint-joseph
# Processing Record 22 of Set 16 | ukiah
# Processing Record 23 of Set 16 | ushtobe
# Processing Record 24 of Set 16 | kabare
# Processing Record 25 of Set 16 | cabatuan
# Processing Record 26 of Set 16 | maumere
# Processing Record 27 of Set 16 | igarka
# Processing Record 28 of Set 16 | camargo
# Processing Record 29 of Set 16 | viloco
# Processing Record 30 of Set 16 | quang ngai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bengkulu  -3.8004  102.2655     84.43        76          58
# 1        Ostrovnoy  68.0531   39.5131     35.13        99         100
# 2      Yellowknife  62.4560 -114.3525     -6.20        94         100
# 3     Port Lincoln -34.7333  135.8667     66.20        68         100
# 4     Rondonopolis -16.4708  -54.6356     67.17        83          13
# 5     Punta Arenas -53.1500  -70.9167     46.51        93         100
# 6    Mar Del Plata -38.0023  -57.5575     57.87        90         100
# 7  Arraial Do Cabo -22.9661  -42.0278     71.13        75           2
# 8         Winthrop  42.3751  -70.9828     44.55        90         100
# 9       Port Hardy  50.6996 -127.4199     42.80        78           1
#
#    Wind Speed Country Current Description
# 0        6.93      ID       broken clouds
# 1       25.23      RU     overcast clouds
# 2        5.23      CA     overcast clouds
# 3       10.11      AU     overcast clouds
# 4        2.91      BR          few clouds
# 5       14.97      CL     overcast clouds
# 6        4.00      AR     overcast clouds
# 7       14.25      BR           clear sky
# 8       10.36      US     overcast clouds
# 9        5.66      CA           clear sky

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data = city_data_df[new_column_order]
city_data.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bengkulu      ID  -3.8004  102.2655     84.43        76          58
# 1        Ostrovnoy      RU  68.0531   39.5131     35.13        99         100
# 2      Yellowknife      CA  62.4560 -114.3525     -6.20        94         100
# 3     Port Lincoln      AU -34.7333  135.8667     66.20        68         100
# 4     Rondonopolis      BR -16.4708  -54.6356     67.17        83          13
# 5     Punta Arenas      CL -53.1500  -70.9167     46.51        93         100
# 6    Mar Del Plata      AR -38.0023  -57.5575     57.87        90         100
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     71.13        75           2
# 8         Winthrop      US  42.3751  -70.9828     44.55        90         100
# 9       Port Hardy      CA  50.6996 -127.4199     42.80        78           1
#
#    Wind Speed Current Description
# 0        6.93       broken clouds
# 1       25.23     overcast clouds
# 2        5.23     overcast clouds
# 3       10.11     overcast clouds
# 4        2.91          few clouds
# 5       14.97     overcast clouds
# 6        4.00     overcast clouds
# 7       14.25           clear sky
# 8       10.36     overcast clouds
# 9        5.66           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
