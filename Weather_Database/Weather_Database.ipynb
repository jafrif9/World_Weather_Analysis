# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_describe = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | ketchikan
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | montrose
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | glendive
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | buchanan
# Processing Record 19 of Set 1 | chicama
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | touros
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | rawson
# Processing Record 24 of Set 1 | porto novo
# Processing Record 25 of Set 1 | sananduva
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | willowmore
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | mae sai
# Processing Record 31 of Set 1 | abbeville
# Processing Record 32 of Set 1 | mehamn
# Processing Record 33 of Set 1 | praia da vitoria
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | naryan-mar
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | tokur
# Processing Record 39 of Set 1 | warrington
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | lompoc
# Processing Record 44 of Set 1 | san quintin
# Processing Record 45 of Set 1 | avera
# Processing Record 46 of Set 1 | mondlo
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | colares
# Processing Record 1 of Set 2 | grand forks
# Processing Record 2 of Set 2 | waitati
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | kinsale
# Processing Record 7 of Set 2 | mamontovo
# Processing Record 8 of Set 2 | shubarshi
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | revelstoke
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | sibolga
# Processing Record 15 of Set 2 | gasa
# Processing Record 16 of Set 2 | ucluelet
# Processing Record 17 of Set 2 | tel aviv-yafo
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | ilo
# Processing Record 21 of Set 2 | makakilo city
# Processing Record 22 of Set 2 | salalah
# Processing Record 23 of Set 2 | beloha
# Processing Record 24 of Set 2 | yumen
# Processing Record 25 of Set 2 | uray
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | ust-maya
# Processing Record 34 of Set 2 | pangnirtung
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | smirnykh
# Processing Record 37 of Set 2 | tual
# Processing Record 38 of Set 2 | kangundo
# Processing Record 39 of Set 2 | tautira
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | staritsa
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | kowary
# Processing Record 46 of Set 2 | vao
# Processing Record 47 of Set 2 | lukulu
# Processing Record 48 of Set 2 | byron bay
# Processing Record 49 of Set 2 | sao felix do xingu
# Processing Record 50 of Set 2 | narsaq
# Processing Record 1 of Set 3 | shelburne
# Processing Record 2 of Set 3 | grimshaw
# Processing Record 3 of Set 3 | suez
# Processing Record 4 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 3 | amberley
# Processing Record 6 of Set 3 | luanda
# Processing Record 7 of Set 3 | varnsdorf
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | qaqortoq
# Processing Record 10 of Set 3 | floro
# Processing Record 11 of Set 3 | horconcitos
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | gaozhou
# Processing Record 14 of Set 3 | gualaceo
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | chengde
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | constitucion
# Processing Record 19 of Set 3 | kawai
# Processing Record 20 of Set 3 | nakamura
# Processing Record 21 of Set 3 | mongagua
# Processing Record 22 of Set 3 | bologoye
# Processing Record 23 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 3 | wuwei
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | liverpool
# Processing Record 27 of Set 3 | camana
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | bhadrachalam
# Processing Record 30 of Set 3 | anchorage
# Processing Record 31 of Set 3 | iskateley
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | ereymentau
# Processing Record 34 of Set 3 | luderitz
# Processing Record 35 of Set 3 | lorengau
# Processing Record 36 of Set 3 | portland
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | abu dhabi
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | vryburg
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | cosamaloapan
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | manokwari
# Processing Record 47 of Set 3 | belyy yar
# Processing Record 48 of Set 3 | launceston
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | pochutla
# Processing Record 1 of Set 4 | riyadh
# Processing Record 2 of Set 4 | yanam
# Processing Record 3 of Set 4 | jiazi
# Processing Record 4 of Set 4 | caravelas
# Processing Record 5 of Set 4 | ihosy
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | tabou
# Processing Record 8 of Set 4 | baykit
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | salur
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | madera
# Processing Record 13 of Set 4 | sosnovo-ozerskoye
# Processing Record 14 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 4 | tigil
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | burns lake
# Processing Record 18 of Set 4 | kavaratti
# Processing Record 19 of Set 4 | pointe michel
# Processing Record 20 of Set 4 | umm kaddadah
# Processing Record 21 of Set 4 | hamilton
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 24 of Set 4 | dunedin
# Processing Record 25 of Set 4 | birao
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 4 | pilar
# Processing Record 30 of Set 4 | longyearbyen
# Processing Record 31 of Set 4 | senanga
# Processing Record 32 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 4 | alghero
# Processing Record 34 of Set 4 | adrar
# Processing Record 35 of Set 4 | broome
# Processing Record 36 of Set 4 | berlevag
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 4 | dikson
# Processing Record 40 of Set 4 | ammokhorion
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | vardo
# Processing Record 43 of Set 4 | pierre
# Processing Record 44 of Set 4 | winnemucca
# Processing Record 45 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 4 | leningradskiy
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | viljoenskroon
# Processing Record 49 of Set 4 | plavinas
# Processing Record 50 of Set 4 | yulara
# Processing Record 1 of Set 5 | topchanchi
# Processing Record 2 of Set 5 | togur
# Processing Record 3 of Set 5 | anadyr
# Processing Record 4 of Set 5 | vestmannaeyjar
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | peniche
# Processing Record 7 of Set 5 | lima
# Processing Record 8 of Set 5 | akyab
# Processing Record 9 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 10 of Set 5 | ayan
# Processing Record 11 of Set 5 | watertown
# Processing Record 12 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 5 | bredasdorp
# Processing Record 14 of Set 5 | miri
# Processing Record 15 of Set 5 | lavrentiya
# Processing Record 16 of Set 5 | manzhouli
# Processing Record 17 of Set 5 | calvinia
# Processing Record 18 of Set 5 | abha
# Processing Record 19 of Set 5 | port elizabeth
# Processing Record 20 of Set 5 | pundaguitan
# Processing Record 21 of Set 5 | puerto del rosario
# Processing Record 22 of Set 5 | erzin
# Processing Record 23 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | cairns
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | araouane
# Processing Record 28 of Set 5 | port keats
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | miranda
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | tari
# Processing Record 33 of Set 5 | kungur
# Processing Record 34 of Set 5 | kaitangata
# Processing Record 35 of Set 5 | yellowknife
# Processing Record 36 of Set 5 | adamov
# Processing Record 37 of Set 5 | karema
# Processing Record 38 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 5 | nowy tomysl
# Processing Record 40 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 5 | high level
# Processing Record 42 of Set 5 | batagay-alyta
# Processing Record 43 of Set 5 | sioux lookout
# Processing Record 44 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 5 | zabol
# Processing Record 46 of Set 5 | bolshoye selo
# Processing Record 47 of Set 5 | stangaceaua
# City not found. Skipping...
# Processing Record 48 of Set 5 | guane
# Processing Record 49 of Set 5 | toguchin
# Processing Record 50 of Set 5 | shetpe
# Processing Record 1 of Set 6 | flin flon
# Processing Record 2 of Set 6 | montague
# Processing Record 3 of Set 6 | meulaboh
# Processing Record 4 of Set 6 | loa janan
# Processing Record 5 of Set 6 | saskylakh
# Processing Record 6 of Set 6 | pavlovsk
# Processing Record 7 of Set 6 | husavik
# Processing Record 8 of Set 6 | daru
# Processing Record 9 of Set 6 | acurenam
# Processing Record 10 of Set 6 | san policarpo
# Processing Record 11 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 6 | tonota
# Processing Record 13 of Set 6 | dingle
# Processing Record 14 of Set 6 | swan river
# Processing Record 15 of Set 6 | dongsheng
# Processing Record 16 of Set 6 | chokurdakh
# Processing Record 17 of Set 6 | amazar
# Processing Record 18 of Set 6 | mount gambier
# Processing Record 19 of Set 6 | srednekolymsk
# Processing Record 20 of Set 6 | vanimo
# Processing Record 21 of Set 6 | blythe
# Processing Record 22 of Set 6 | tuatapere
# Processing Record 23 of Set 6 | san carlos de bariloche
# Processing Record 24 of Set 6 | nelson bay
# Processing Record 25 of Set 6 | coihaique
# Processing Record 26 of Set 6 | yaan
# Processing Record 27 of Set 6 | emerald
# Processing Record 28 of Set 6 | strezhevoy
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | tagusao
# Processing Record 31 of Set 6 | vaitape
# Processing Record 32 of Set 6 | kualakapuas
# Processing Record 33 of Set 6 | tupelo
# Processing Record 34 of Set 6 | pisco
# Processing Record 35 of Set 6 | nancha
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | saint-joseph
# Processing Record 38 of Set 6 | cabinda
# Processing Record 39 of Set 6 | teahupoo
# Processing Record 40 of Set 6 | norway
# Processing Record 41 of Set 6 | petrivka
# Processing Record 42 of Set 6 | leiyang
# Processing Record 43 of Set 6 | makat
# Processing Record 44 of Set 6 | yeppoon
# Processing Record 45 of Set 6 | ossora
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | almenevo
# City not found. Skipping...
# Processing Record 48 of Set 6 | asht
# City not found. Skipping...
# Processing Record 49 of Set 6 | taoudenni
# Processing Record 50 of Set 6 | salinopolis
# Processing Record 1 of Set 7 | lakatoro
# Processing Record 2 of Set 7 | harnosand
# Processing Record 3 of Set 7 | kieta
# Processing Record 4 of Set 7 | labuhan
# Processing Record 5 of Set 7 | ahipara
# Processing Record 6 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 7 | lumby
# Processing Record 8 of Set 7 | lalmohan
# Processing Record 9 of Set 7 | perelyub
# Processing Record 10 of Set 7 | tres arroyos
# Processing Record 11 of Set 7 | westport
# Processing Record 12 of Set 7 | asfi
# Processing Record 13 of Set 7 | nuevo progreso
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | fukue
# Processing Record 16 of Set 7 | tarakan
# Processing Record 17 of Set 7 | ornskoldsvik
# Processing Record 18 of Set 7 | parana
# Processing Record 19 of Set 7 | sao filipe
# Processing Record 20 of Set 7 | hermiston
# Processing Record 21 of Set 7 | porto walter
# Processing Record 22 of Set 7 | jumla
# Processing Record 23 of Set 7 | pevek
# Processing Record 24 of Set 7 | eyl
# Processing Record 25 of Set 7 | mollendo
# Processing Record 26 of Set 7 | gazanjyk
# Processing Record 27 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 7 | ca mau
# Processing Record 29 of Set 7 | biloela
# Processing Record 30 of Set 7 | khasan
# Processing Record 31 of Set 7 | kahului
# Processing Record 32 of Set 7 | trairi
# Processing Record 33 of Set 7 | aleksandrov gay
# Processing Record 34 of Set 7 | jiuquan
# Processing Record 35 of Set 7 | vila velha
# Processing Record 36 of Set 7 | san luis
# Processing Record 37 of Set 7 | wad rawah
# Processing Record 38 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 7 | tudor vladimirescu
# Processing Record 40 of Set 7 | santarem
# Processing Record 41 of Set 7 | santa ines
# Processing Record 42 of Set 7 | ngunguru
# Processing Record 43 of Set 7 | cabedelo
# Processing Record 44 of Set 7 | omboue
# Processing Record 45 of Set 7 | aloleng
# Processing Record 46 of Set 7 | kikwit
# Processing Record 47 of Set 7 | manicore
# Processing Record 48 of Set 7 | devyatka
# City not found. Skipping...
# Processing Record 49 of Set 7 | sobolevo
# Processing Record 50 of Set 7 | el puente
# Processing Record 1 of Set 8 | cururupu
# Processing Record 2 of Set 8 | port hedland
# Processing Record 3 of Set 8 | sao joao batista
# Processing Record 4 of Set 8 | buraydah
# Processing Record 5 of Set 8 | bograd
# Processing Record 6 of Set 8 | comodoro rivadavia
# Processing Record 7 of Set 8 | waikuku
# Processing Record 8 of Set 8 | todos santos
# Processing Record 9 of Set 8 | sakakah
# Processing Record 10 of Set 8 | nanortalik
# Processing Record 11 of Set 8 | chiang khong
# Processing Record 12 of Set 8 | areia branca
# Processing Record 13 of Set 8 | kot diji
# Processing Record 14 of Set 8 | naze
# Processing Record 15 of Set 8 | deputatskiy
# Processing Record 16 of Set 8 | juan aldama
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | ancud
# Processing Record 20 of Set 8 | morris
# Processing Record 21 of Set 8 | pangody
# Processing Record 22 of Set 8 | mana
# Processing Record 23 of Set 8 | mega
# Processing Record 24 of Set 8 | safaga
# Processing Record 25 of Set 8 | neiafu
# Processing Record 26 of Set 8 | entebbe
# Processing Record 27 of Set 8 | sitka
# Processing Record 28 of Set 8 | ust-kuyga
# Processing Record 29 of Set 8 | pangai
# Processing Record 30 of Set 8 | roma
# Processing Record 31 of Set 8 | yarim
# Processing Record 32 of Set 8 | temiscaming
# Processing Record 33 of Set 8 | chernyshevskiy
# Processing Record 34 of Set 8 | muros
# Processing Record 35 of Set 8 | san andres
# Processing Record 36 of Set 8 | bima
# Processing Record 37 of Set 8 | clyde river
# Processing Record 38 of Set 8 | lengshuitan
# Processing Record 39 of Set 8 | sirnak
# Processing Record 40 of Set 8 | okhotsk
# Processing Record 41 of Set 8 | rocha
# Processing Record 42 of Set 8 | port lincoln
# Processing Record 43 of Set 8 | ponta do sol
# Processing Record 44 of Set 8 | atbasar
# Processing Record 45 of Set 8 | baruun-urt
# Processing Record 46 of Set 8 | remedios
# Processing Record 47 of Set 8 | palmer
# Processing Record 48 of Set 8 | baiyin
# Processing Record 49 of Set 8 | havelock
# Processing Record 50 of Set 8 | donskoye
# Processing Record 1 of Set 9 | tirano
# Processing Record 2 of Set 9 | kefamenanu
# Processing Record 3 of Set 9 | faqirwali
# Processing Record 4 of Set 9 | reconquista
# Processing Record 5 of Set 9 | port hardy
# Processing Record 6 of Set 9 | aykhal
# Processing Record 7 of Set 9 | ballina
# Processing Record 8 of Set 9 | los llanos de aridane
# Processing Record 9 of Set 9 | cave spring
# Processing Record 10 of Set 9 | sisimiut
# Processing Record 11 of Set 9 | tiarei
# Processing Record 12 of Set 9 | aberystwyth
# Processing Record 13 of Set 9 | las lomas
# Processing Record 14 of Set 9 | svobodnyy
# Processing Record 15 of Set 9 | un
# City not found. Skipping...
# Processing Record 16 of Set 9 | praia
# Processing Record 17 of Set 9 | guiong
# Processing Record 18 of Set 9 | grand gaube
# Processing Record 19 of Set 9 | san vicente
# Processing Record 20 of Set 9 | maykor
# Processing Record 21 of Set 9 | loreto
# Processing Record 22 of Set 9 | havre-saint-pierre
# Processing Record 23 of Set 9 | korla
# Processing Record 24 of Set 9 | talgar
# Processing Record 25 of Set 9 | jonkoping
# Processing Record 26 of Set 9 | kununurra
# Processing Record 27 of Set 9 | darhan
# Processing Record 28 of Set 9 | mersing
# Processing Record 29 of Set 9 | aksu
# Processing Record 30 of Set 9 | garowe
# Processing Record 31 of Set 9 | pushkino
# Processing Record 32 of Set 9 | itaqui
# Processing Record 33 of Set 9 | sao jose do belmonte
# Processing Record 34 of Set 9 | alofi
# Processing Record 35 of Set 9 | gemlik
# Processing Record 36 of Set 9 | mandalgovi
# Processing Record 37 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 38 of Set 9 | akdepe
# Processing Record 39 of Set 9 | micheweni
# Processing Record 40 of Set 9 | katsuura
# Processing Record 41 of Set 9 | codrington
# Processing Record 42 of Set 9 | raton
# Processing Record 43 of Set 9 | cockburn town
# Processing Record 44 of Set 9 | enzan
# Processing Record 45 of Set 9 | shingu
# Processing Record 46 of Set 9 | pauini
# Processing Record 47 of Set 9 | porto santo
# Processing Record 48 of Set 9 | barao de melgaco
# Processing Record 49 of Set 9 | gbarnga
# Processing Record 50 of Set 9 | edd
# Processing Record 1 of Set 10 | vila franca do campo
# Processing Record 2 of Set 10 | nushki
# Processing Record 3 of Set 10 | kalmunai
# Processing Record 4 of Set 10 | vidalia
# Processing Record 5 of Set 10 | beringovskiy
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | tweed
# Processing Record 8 of Set 10 | letlhakeng
# Processing Record 9 of Set 10 | green river
# Processing Record 10 of Set 10 | port shepstone
# Processing Record 11 of Set 10 | urumqi
# Processing Record 12 of Set 10 | goderich
# Processing Record 13 of Set 10 | mitsamiouli
# Processing Record 14 of Set 10 | alpena
# Processing Record 15 of Set 10 | takoradi
# Processing Record 16 of Set 10 | los cedrales
# Processing Record 17 of Set 10 | gushikawa
# Processing Record 18 of Set 10 | salinas
# Processing Record 19 of Set 10 | hualmay
# Processing Record 20 of Set 10 | nara
# Processing Record 21 of Set 10 | bugene
# Processing Record 22 of Set 10 | apolda
# Processing Record 23 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 10 | kaniama
# Processing Record 25 of Set 10 | komsomolskiy
# Processing Record 26 of Set 10 | ilulissat
# Processing Record 27 of Set 10 | iracoubo
# Processing Record 28 of Set 10 | nyrob
# Processing Record 29 of Set 10 | shimoda
# Processing Record 30 of Set 10 | kawalu
# Processing Record 31 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 10 | medina
# Processing Record 33 of Set 10 | coquimbo
# Processing Record 34 of Set 10 | nueva gerona
# Processing Record 35 of Set 10 | kaberamaido
# Processing Record 36 of Set 10 | nuevo ideal
# Processing Record 37 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 10 | tommot
# Processing Record 39 of Set 10 | hobyo
# Processing Record 40 of Set 10 | arlit
# Processing Record 41 of Set 10 | necochea
# Processing Record 42 of Set 10 | kemijarvi
# Processing Record 43 of Set 10 | roebourne
# Processing Record 44 of Set 10 | barrhead
# Processing Record 45 of Set 10 | usinsk
# Processing Record 46 of Set 10 | chifeng
# Processing Record 47 of Set 10 | san rafael
# Processing Record 48 of Set 10 | carutapera
# Processing Record 49 of Set 10 | shahrud
# Processing Record 50 of Set 10 | haines junction
# Processing Record 1 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 2 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 11 | high prairie
# Processing Record 4 of Set 11 | northam
# Processing Record 5 of Set 11 | cotonou
# Processing Record 6 of Set 11 | portpatrick
# City not found. Skipping...
# Processing Record 7 of Set 11 | guerrero negro
# Processing Record 8 of Set 11 | iqaluit
# Processing Record 9 of Set 11 | lubango
# Processing Record 10 of Set 11 | saldanha
# Processing Record 11 of Set 11 | itapora
# Processing Record 12 of Set 11 | leh
# Processing Record 13 of Set 11 | honiara
# Processing Record 14 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 15 of Set 11 | la tuque
# Processing Record 16 of Set 11 | port blair
# Processing Record 17 of Set 11 | turkmenabat
# Processing Record 18 of Set 11 | kristinehamn
# Processing Record 19 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 21 of Set 11 | ulladulla
# Processing Record 22 of Set 11 | killybegs
# Processing Record 23 of Set 11 | jambusar
# Processing Record 24 of Set 11 | goya
# Processing Record 25 of Set 11 | valparaiso
# Processing Record 26 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 28 of Set 11 | kwinana
# Processing Record 29 of Set 11 | kilindoni
# Processing Record 30 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 11 | udachnyy
# Processing Record 32 of Set 11 | laslea
# Processing Record 33 of Set 11 | ahuimanu
# Processing Record 34 of Set 11 | nandikotkur
# Processing Record 35 of Set 11 | loandjili
# Processing Record 36 of Set 11 | batemans bay
# Processing Record 37 of Set 11 | poli
# Processing Record 38 of Set 11 | mecca
# Processing Record 39 of Set 11 | lagoa
# Processing Record 40 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 11 | sergeyevka
# Processing Record 42 of Set 11 | ushtobe
# Processing Record 43 of Set 11 | barranca
# Processing Record 44 of Set 11 | mayo
# Processing Record 45 of Set 11 | brigantine
# Processing Record 46 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 11 | matara
# Processing Record 48 of Set 11 | syracuse
# Processing Record 49 of Set 11 | falakata
# Processing Record 50 of Set 11 | inhambane
# Processing Record 1 of Set 12 | staryy nadym
# Processing Record 2 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 3 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 4 of Set 12 | chhatapur
# Processing Record 5 of Set 12 | severodvinsk
# Processing Record 6 of Set 12 | badou
# Processing Record 7 of Set 12 | novoagansk
# Processing Record 8 of Set 12 | predivinsk
# Processing Record 9 of Set 12 | puerto escondido
# Processing Record 10 of Set 12 | thinadhoo
# Processing Record 11 of Set 12 | prince rupert
# Processing Record 12 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 12 | raudeberg
# Processing Record 14 of Set 12 | flinders
# Processing Record 15 of Set 12 | soure
# Processing Record 16 of Set 12 | coolum beach
# Processing Record 17 of Set 12 | moussoro
# Processing Record 18 of Set 12 | amahai
# Processing Record 19 of Set 12 | the pas
# Processing Record 20 of Set 12 | alenquer
# Processing Record 21 of Set 12 | upata
# Processing Record 22 of Set 12 | bilibino
# Processing Record 23 of Set 12 | khao yoi
# Processing Record 24 of Set 12 | maunatlala
# Processing Record 25 of Set 12 | margate
# Processing Record 26 of Set 12 | bara
# Processing Record 27 of Set 12 | iralaya
# Processing Record 28 of Set 12 | axim
# Processing Record 29 of Set 12 | cepu
# Processing Record 30 of Set 12 | portobelo
# Processing Record 31 of Set 12 | kapit
# Processing Record 32 of Set 12 | alberton
# Processing Record 33 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 12 | huilong
# Processing Record 35 of Set 12 | gagra
# Processing Record 36 of Set 12 | rio grande
# Processing Record 37 of Set 12 | nago
# Processing Record 38 of Set 12 | tsogni
# Processing Record 39 of Set 12 | pacific grove
# Processing Record 40 of Set 12 | hay river
# Processing Record 41 of Set 12 | ferrol
# Processing Record 42 of Set 12 | mocuba
# Processing Record 43 of Set 12 | vilani
# Processing Record 44 of Set 12 | sao joao da barra
# Processing Record 45 of Set 12 | melo
# Processing Record 46 of Set 12 | tabuk
# Processing Record 47 of Set 12 | minas
# Processing Record 48 of Set 12 | mbandaka
# Processing Record 49 of Set 12 | nibbar
# Processing Record 50 of Set 12 | dicabisagan
# Processing Record 1 of Set 13 | kalianget
# Processing Record 2 of Set 13 | sola
# Processing Record 3 of Set 13 | alice springs
# Processing Record 4 of Set 13 | lasem
# Processing Record 5 of Set 13 | fairbanks
# Processing Record 6 of Set 13 | talnakh
# Processing Record 7 of Set 13 | booue
# Processing Record 8 of Set 13 | cortez
# Processing Record 9 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 10 of Set 13 | ponta delgada
# Processing Record 11 of Set 13 | fort frances
# Processing Record 12 of Set 13 | uribia
# Processing Record 13 of Set 13 | matagami
# Processing Record 14 of Set 13 | dados
# City not found. Skipping...
# Processing Record 15 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 13 | verkh-usugli
# Processing Record 18 of Set 13 | san jose de ocoa
# Processing Record 19 of Set 13 | broken hill
# Processing Record 20 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 13 | hami
# Processing Record 22 of Set 13 | aklavik
# Processing Record 23 of Set 13 | mozarlandia
# Processing Record 24 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 25 of Set 13 | gat
# Processing Record 26 of Set 13 | soyo
# Processing Record 27 of Set 13 | sonderborg
# Processing Record 28 of Set 13 | finnsnes
# Processing Record 29 of Set 13 | aiquile
# Processing Record 30 of Set 13 | cabo san lucas
# Processing Record 31 of Set 13 | morgan city
# Processing Record 32 of Set 13 | pontian kecil
# Processing Record 33 of Set 13 | half moon bay
# Processing Record 34 of Set 13 | faya
# Processing Record 35 of Set 13 | te anau
# Processing Record 36 of Set 13 | nome
# Processing Record 37 of Set 13 | kontagora
# Processing Record 38 of Set 13 | indianola
# Processing Record 39 of Set 13 | bereda
# Processing Record 40 of Set 13 | hinton
# Processing Record 41 of Set 13 | geraldton
# Processing Record 42 of Set 13 | shumskiy
# Processing Record 43 of Set 13 | ha tinh
# Processing Record 44 of Set 13 | clara
# Processing Record 45 of Set 13 | ginda
# Processing Record 46 of Set 13 | formosa
# Processing Record 47 of Set 13 | quartucciu
# Processing Record 48 of Set 13 | wladyslawowo
# Processing Record 49 of Set 13 | ankazoabo
# Processing Record 50 of Set 13 | anaconda
# Processing Record 1 of Set 14 | hecun
# Processing Record 2 of Set 14 | grindavik
# Processing Record 3 of Set 14 | kisaran
# Processing Record 4 of Set 14 | kangaatsiaq
# Processing Record 5 of Set 14 | luoyang
# Processing Record 6 of Set 14 | dustlik
# Processing Record 7 of Set 14 | boa vista
# Processing Record 8 of Set 14 | padang
# Processing Record 9 of Set 14 | chenzhou
# Processing Record 10 of Set 14 | maragogi
# Processing Record 11 of Set 14 | sambava
# Processing Record 12 of Set 14 | xining
# Processing Record 13 of Set 14 | waingapu
# Processing Record 14 of Set 14 | villa maria
# Processing Record 15 of Set 14 | viedma
# Processing Record 16 of Set 14 | omsukchan
# Processing Record 17 of Set 14 | north platte
# Processing Record 18 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 14 | maniitsoq
# Processing Record 20 of Set 14 | deer lake
# Processing Record 21 of Set 14 | pathein
# Processing Record 22 of Set 14 | bathsheba
# Processing Record 23 of Set 14 | sfantu gheorghe
# Processing Record 24 of Set 14 | ambon
# Processing Record 25 of Set 14 | livingstone
# Processing Record 26 of Set 14 | benxi
# Processing Record 27 of Set 14 | bartica
# Processing Record 28 of Set 14 | tadine
# Processing Record 29 of Set 14 | turinsk
# Processing Record 30 of Set 14 | pingliang
# Processing Record 31 of Set 14 | agadir
# Processing Record 32 of Set 14 | san juan
# Processing Record 33 of Set 14 | vigrestad
# Processing Record 34 of Set 14 | fort dodge
# Processing Record 35 of Set 14 | puerto plata
# Processing Record 36 of Set 14 | nong phai
# Processing Record 37 of Set 14 | sibu
# Processing Record 38 of Set 14 | trail
# Processing Record 39 of Set 14 | preobrazheniye
# Processing Record 40 of Set 14 | bambanglipuro
# Processing Record 41 of Set 14 | shalinskoye
# Processing Record 42 of Set 14 | gazojak
# Processing Record 43 of Set 14 | eureka
# Processing Record 44 of Set 14 | harper
# Processing Record 45 of Set 14 | opuwo
# Processing Record 46 of Set 14 | puri
# Processing Record 47 of Set 14 | kosonsoy
# Processing Record 48 of Set 14 | porosozero
# Processing Record 49 of Set 14 | madison
# Processing Record 50 of Set 14 | namibe
# Processing Record 1 of Set 15 | yarensk
# Processing Record 2 of Set 15 | granby
# Processing Record 3 of Set 15 | kindu
# Processing Record 4 of Set 15 | mogadouro
# Processing Record 5 of Set 15 | yerbogachen
# Processing Record 6 of Set 15 | alto parana
# Processing Record 7 of Set 15 | sao raimundo nonato
# Processing Record 8 of Set 15 | buala
# Processing Record 9 of Set 15 | tucumcari
# Processing Record 10 of Set 15 | roela
# Processing Record 11 of Set 15 | qom
# Processing Record 12 of Set 15 | cernay
# Processing Record 13 of Set 15 | chikoy
# City not found. Skipping...
# Processing Record 14 of Set 15 | surt
# Processing Record 15 of Set 15 | solnechnyy
# Processing Record 16 of Set 15 | celestun
# Processing Record 17 of Set 15 | krasnoselkup
# Processing Record 18 of Set 15 | hovd
# Processing Record 19 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 20 of Set 15 | likasi
# Processing Record 21 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 22 of Set 15 | sharjah
# Processing Record 23 of Set 15 | sarapul
# Processing Record 24 of Set 15 | superior
# Processing Record 25 of Set 15 | bubaque
# Processing Record 26 of Set 15 | ndele
# Processing Record 27 of Set 15 | ondo
# Processing Record 28 of Set 15 | nybro
# Processing Record 29 of Set 15 | qinggang
# Processing Record 30 of Set 15 | sao geraldo do araguaia
# Processing Record 31 of Set 15 | lermontovka
# Processing Record 32 of Set 15 | santa helena de goias
# Processing Record 33 of Set 15 | maceio
# Processing Record 34 of Set 15 | kambove
# Processing Record 35 of Set 15 | varnamo
# Processing Record 36 of Set 15 | krasnoarmeysk
# Processing Record 37 of Set 15 | biak
# Processing Record 38 of Set 15 | golfito
# Processing Record 39 of Set 15 | shagonar
# Processing Record 40 of Set 15 | xiazhen
# Processing Record 41 of Set 15 | seoul
# Processing Record 42 of Set 15 | hobbs
# Processing Record 43 of Set 15 | phan thiet
# Processing Record 44 of Set 15 | san ramon
# Processing Record 45 of Set 15 | boende
# Processing Record 46 of Set 15 | bom jesus
# Processing Record 47 of Set 15 | gamba
# Processing Record 48 of Set 15 | novo aripuana
# Processing Record 49 of Set 15 | rakovski
# Processing Record 50 of Set 15 | kilcullen
# Processing Record 1 of Set 16 | orimattila
# Processing Record 2 of Set 16 | fare
# Processing Record 3 of Set 16 | miandrivazo
# Processing Record 4 of Set 16 | virovitica
# Processing Record 5 of Set 16 | la ronge
# Processing Record 6 of Set 16 | kurilsk
# Processing Record 7 of Set 16 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 16 | fez
# Processing Record 9 of Set 16 | natal
# Processing Record 10 of Set 16 | porbandar
# Processing Record 11 of Set 16 | zhuzhou
# Processing Record 12 of Set 16 | khuzdar
# Processing Record 13 of Set 16 | hollola
# Processing Record 14 of Set 16 | kanturk
# Processing Record 15 of Set 16 | bridlington
# Processing Record 16 of Set 16 | whitianga
# Processing Record 17 of Set 16 | mayumba
# Processing Record 18 of Set 16 | katobu
# Processing Record 19 of Set 16 | samana
# Processing Record 20 of Set 16 | patos
# Processing Record 21 of Set 16 | honningsvag
# Processing Record 22 of Set 16 | hadrut
# Processing Record 23 of Set 16 | cangzhou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Hermanus -34.4187   19.2345     63.81        64           7       10.85
# 1    Busselton -33.6500  115.3333     65.95        45           3       13.38
# 2    Ketchikan  55.3422 -131.6461     37.38        69           0        0.00
# 3  Port Alfred -33.5906   26.8910     68.18        74          91        1.01
# 4        Vaini -21.2000 -175.2000     77.16        94          20        3.44
# 5     Montrose  38.4166 -108.2673     37.51        68           0        8.43
# 6       Albany  42.6001  -73.9662     36.41        83          32       11.01
# 7     Khatanga  71.9667  102.5000     24.06        91         100       10.49
# 8      Kavieng  -2.5744  150.7967     83.71        73          83       13.18
# 9     Glendive  47.1053 -104.7125     28.02        73         100       17.27
#
#   Country Current Description
# 0      ZA           clear sky
# 1      AU           clear sky
# 2      US           clear sky
# 3      ZA     overcast clouds
# 4      TO          few clouds
# 5      US           clear sky
# 6      US    scattered clouds
# 7      RU     overcast clouds
# 8      PG          light rain
# 9      US     overcast clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data = city_data_df[new_column_order]
city_data.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hermanus      ZA -34.4187   19.2345     63.81        64           7
# 1    Busselton      AU -33.6500  115.3333     65.95        45           3
# 2    Ketchikan      US  55.3422 -131.6461     37.38        69           0
# 3  Port Alfred      ZA -33.5906   26.8910     68.18        74          91
# 4        Vaini      TO -21.2000 -175.2000     77.16        94          20
# 5     Montrose      US  38.4166 -108.2673     37.51        68           0
# 6       Albany      US  42.6001  -73.9662     36.41        83          32
# 7     Khatanga      RU  71.9667  102.5000     24.06        91         100
# 8      Kavieng      PG  -2.5744  150.7967     83.71        73          83
# 9     Glendive      US  47.1053 -104.7125     28.02        73         100
#
#    Wind Speed Current Description
# 0       10.85           clear sky
# 1       13.38           clear sky
# 2        0.00           clear sky
# 3        1.01     overcast clouds
# 4        3.44          few clouds
# 5        8.43           clear sky
# 6       11.01    scattered clouds
# 7       10.49     overcast clouds
# 8       13.18          light rain
# 9       17.27     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
